# %%
print('hello')
# Out:
# hello

# %% [markdown]
# <h1>Importing pandas</h1>

# %%
import pandas as pd

# %%
pd.read_csv('all_champions_trophy_matches_results.csv')
# Out:
#             Team1        Team2                                  Toss  \
# 0    South Africa  West Indies  South Africa, elected to field first
# 1           India  West Indies           India, elected to bat first
# 2    South Africa    Sri Lanka     Sri Lanka, elected to field first
# 3        Pakistan  West Indies     West Indies, elected to bat first
# 4       Australia        India     Australia, elected to field first
# ..            ...          ...                                   ...
# 110     Australia   Bangladesh      Bangladesh, elected to bat first
# 111         India     Pakistan      Pakistan, elected to field first
# 112  South Africa    Sri Lanka     Sri Lanka, elected to field first
# 113     Australia  New Zealand     New Zealand, elected to bat first
# 114       England   Bangladesh       England, elected to field first
#
#     Match days        Winner Player of the Match     Margin      Ground  \
# ...

# %%
pd.read_csv('demo_mlexpec.tsv',sep='\t')
# Out:
#       unit,sex,age,geo\time 2021   2020   2019   2018   2017    2016   2015   \
# 0                YR,F,Y1,AL    :   79.4   80.4   80.2   79.7    79.8   79.2
# 1                YR,F,Y1,AM    :      :   79.1   79.2   78.5    78.0   77.9
# 2                YR,F,Y1,AT    :   82.9   83.5   83.3   83.2    83.4   83.0
# 3                YR,F,Y1,AZ    :      :   78.6   78.1   77.7       :   77.5
# 4                YR,F,Y1,BE    :   82.3   83.6   83.2   83.2    83.2   82.6
# ...                     ...   ...    ...    ...    ...    ...     ...    ...
# 14443         YR,T,Y_LT1,SM    :      :      :      :      :       :      :
# 14444         YR,T,Y_LT1,TR    :      :   79.1   78.9   78.5    78.1   78.2
# 14445         YR,T,Y_LT1,UA    :      :   73.4   73.2   73.3    72.9   72.5
# 14446         YR,T,Y_LT1,UK    :      :      :   81.3   81.3    81.2   81.0
# 14447         YR,T,Y_LT1,XK    :      :      :      :      :   78.6 p     :
#
# ...

# %% [markdown]
# <h1>Open csv file from url</h1>

# %%
import requests
from io import StringIO
url='https://github.com/aishwaryamate/Datasets/blob/main/aug_train.csv'
 headers={'','',''}
req=requests.get(url,headers=headers)
data = stringIO.get(req.text)
pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       3 url='https://github.com/aishwaryamate/Datasets/blob/main/aug_train.csv'
#       4 # headers={'','',''}
# ----> 5 req=requests.get(url,headers=headers)
#       6 data = stringIO.get(req.text)
#       7 pd.read_csv(data)
#
# NameError: name 'headers' is not defined

# %% [markdown]
# <h1>here are some important function that will use in future machine learning prolems</h1>

# %%
# skiprows----> for desire rows
# nrows------> for limited number of rows
# encoding parameter   encoding='latin -1'
# skip bad lines ---> error_bad_lines=False
# dtype parameter --> use for save memory
# parse_dates---> use for handling dates
# convertors---> convertors={'':  }
# na_values=['']--> for convert irrelevant values to nan
# loading a huge dataset in chunks ---> chunksize=5000
# index_col for making column to index
# header=[1] ---> making row to columns name
# use_cols=['','','',] for desire column

# %% [markdown]
# <h1>Working with JSON</h1>

# %%
pd.read_json('')

# %% [markdown]
# <h1>Working with SQL file</h1>

# %%
pip install mysql.connector
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
# ...

# %%
import mysql.connector
con=mysql.connector.connect(host='localhost',user='root',password='(ABCDHammad123@)',database='blood_donation')
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 import mysql.connector
# ----> 2 con=mysql.connector.connect(host='localhost',user='root',password='(ABCDHammad123@)',database='blood_donation')
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# ...
